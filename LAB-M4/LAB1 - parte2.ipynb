# %%
import pandas as pd

data = pd.read_csv('costumers.csv')

data.head()
# Out:
#     Salario  Credito_tipo_1  Credito_tipo_2  Limite_TC  Tiempo_cliente  \
# 0  22572.91               1               0   30136.74             0.0
# 1  10609.64               1               1   53623.94             0.0
# 2  10079.48               0               1   18135.44             0.0
# 3  13871.35               1               0   30831.75             0.0
# 4   6541.46               0               1   20626.23             0.0
#
#    Producto_ofrecido
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  0

# %% [markdown]
# # EDA

# %%
data.shape
# Out:
# (500, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Salario            500 non-null    float64
#  1   Credito_tipo_1     500 non-null    int64
#  2   Credito_tipo_2     500 non-null    int64
#  3   Limite_TC          500 non-null    float64
#  4   Tiempo_cliente     500 non-null    float64
#  5   Producto_ofrecido  500 non-null    int64
# dtypes: float64(3), int64(3)
# memory usage: 23.6 KB

# %%
data.describe()
# Out:
#             Salario  Credito_tipo_1  Credito_tipo_2      Limite_TC  \
# count    500.000000      500.000000      500.000000     500.000000
# mean   12089.097380        0.610000        0.458000   44784.554960
# std     5123.700116        0.488238        0.498732   22150.923996
# min    -2911.650000        0.000000        0.000000  -22207.950000
# 25%     8534.350000        0.000000        0.000000   30096.285000
# 50%    11438.600000        1.000000        0.000000   47991.515000
# 75%    15171.467500        1.000000        1.000000   59108.175000
# max    30041.400000        1.000000        1.000000  118636.820000
#
#        Tiempo_cliente  Producto_ofrecido
# count      500.000000         500.000000
# mean         4.327000           0.602000
# std          4.784776           0.489976
# min          0.000000           0.000000
# 25%          0.000000           0.000000
# 50%          0.000000           1.000000
# 75%          8.400000           1.000000
# ...

# %%
data.isnull().sum()
# Out:
# Salario              0
# Credito_tipo_1       0
# Credito_tipo_2       0
# Limite_TC            0
# Tiempo_cliente       0
# Producto_ofrecido    0
# dtype: int64

# %%
data['Credito_tipo_1'].value_counts()
# Out:
# Credito_tipo_1
# 1    305
# 0    195
# Name: count, dtype: int64

# %%
pd.crosstab(data['Credito_tipo_1'], data['Producto_ofrecido'])
# Out:
# Producto_ofrecido    0    1
# Credito_tipo_1
# 0                   76  119
# 1                  123  182

# %%
import matplotlib.pyplot as plt

plt.hist(data['Salario'])
# Out:
# (array([  3.,  13.,  58., 127., 119.,  89.,  60.,  20.,   7.,   4.]),
#  array([-2911.65 ,   383.655,  3678.96 ,  6974.265, 10269.57 , 13564.875,
#         16860.18 , 20155.485, 23450.79 , 26746.095, 30041.4  ]),
#  <BarContainer object of 10 artists>)

# %%
data['Salario'].mean()
# Out:
# 12089.09738

# %%
data['Salario'].median()
# Out:
# 11438.6

# %% [markdown]
# # ESCALADO DE DATOS

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(data)

# %% [markdown]
# # METODO DEL CODO

# %%
from sklearn.cluster import KMeans

# %%
inertia = []
K = range(1, 10)

for k in K:
    model = KMeans(n_clusters=k, random_state=42)
    model.fit(X_scaled)
    inertia.append(model.inertia_)

plt.plot(K, inertia, '-o')

# %% [markdown]
# # K-MEANS

# %%
kmeans = KMeans(n_clusters=2, random_state=42)
data['cluster_kmeans'] = kmeans.fit_predict(X_scaled)

data.head()
# Out:
#     Salario  Credito_tipo_1  Credito_tipo_2  Limite_TC  Tiempo_cliente  \
# 0  22572.91               1               0   30136.74             0.0
# 1  10609.64               1               1   53623.94             0.0
# 2  10079.48               0               1   18135.44             0.0
# 3  13871.35               1               0   30831.75             0.0
# 4   6541.46               0               1   20626.23             0.0
#
#    Producto_ofrecido  cluster_kmeans
# 0                  1               0
# 1                  1               1
# 2                  0               1
# 3                  1               0
# 4                  0               1

# %%
data['cluster_kmeans'].value_counts()
# Out:
# cluster_kmeans
# 0    272
# 1    228
# Name: count, dtype: int64

# %% [markdown]
# # ANALISIS DE COMPONENTES PRINCIPALES (PCA)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components = 2)
X_pca = pca.fit_transform(X_scaled)

# %%
# TRANSFORMAR A DATAFRAME DE PANDAS

pca_df = pd.DataFrame(X_pca, columns=['PCA1', 'PCA2'])
pca_df['cluster'] = data['cluster_kmeans']

# %%
plt.scatter(pca_df['PCA1'], pca_df['PCA2'], c=pca_df['cluster'], cmap='viridis')

# %%
from sklearn.metrics import silhouette_score
silueta_kmeans = silhouette_score(X_scaled, data['cluster_kmeans'])
silueta_kmeans
# Out:
# 0.31469048997662175

# %%
# !pip install joblib

# %%
import joblib

# %%
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
joblib.dump(pca, "pca.pkl")
# Out:
# ['pca.pkl']

# %%
joblib.dump(kmeans, "kmeans.pkl")
# Out:
# ['kmeans.pkl']

# %% [markdown]
# # NUEVOS CLIENTES

# %%
data_new = pd.read_csv('new_costumer.csv')
data_new.head()
# Out:
#     Salario  Credito_tipo_1  Credito_tipo_2  Limite_TC  Tiempo_cliente  \
# 0  19028.02               1               0   18845.91             0.0
# 1  17004.81               1               0   16421.36             0.0
# 2  12973.54               1               0   57295.44             9.6
# 3  13995.43               0               0   23556.17             7.7
# 4  13155.66               0               1   61073.59            10.2
#
#    Producto_ofrecido  Tipo_de_cliente
# 0                  1                3
# 1                  0                2
# 2                  1                2
# 3                  0                3
# 4                  1                0

# %%
data_new['Tipo_de_cliente'].value_counts()
# Out:
# Tipo_de_cliente
# 0    14
# 1    14
# 3    11
# 2    11
# Name: count, dtype: int64

# %%
data_new.drop(data_new['Tipo_de_cliente'], axis=0)
# Out:
#      Salario  Credito_tipo_1  Credito_tipo_2  Limite_TC  Tiempo_cliente  \
# 4   13155.66               0               1   61073.59            10.2
# 5    4195.63               0               1   46424.81             0.0
# 6    9676.05               1               0   36202.91             0.0
# 7    3192.72               1               1   76851.08             6.4
# 8    7539.78               0               1   62530.44            11.3
# 9    7271.86               1               0   64016.47             5.3
# 10   7159.60               0               1   42764.55             5.9
# 11  10565.71               0               1   16390.62             0.0
# 12   3048.88               1               1   63182.60             0.0
# 13  23628.51               1               0   16411.34             0.0
# 14  19636.41               1               0   38834.02             0.0
# 15  16038.73               1               0   43792.57             0.0
# ...

# %%
features = ['Salario', 'Credito_tipo_1', 'Credito_tipo_2', 'Limite_TC', 'Tiempo_cliente', 'Producto_ofrecido']
X_new = data_new[features]

# %%
X_new_scaled = scaler.transform(X_new)

# %%
data_new['cluster_pred'] = kmeans.predict(X_new_scaled)
data_new.head()
# Out:
#     Salario  Credito_tipo_1  Credito_tipo_2  Limite_TC  Tiempo_cliente  \
# 0  19028.02               1               0   18845.91             0.0
# 1  17004.81               1               0   16421.36             0.0
# 2  12973.54               1               0   57295.44             9.6
# 3  13995.43               0               0   23556.17             7.7
# 4  13155.66               0               1   61073.59            10.2
#
#    Producto_ofrecido  Tipo_de_cliente  cluster_pred
# 0                  1                3             0
# 1                  0                2             0
# 2                  1                2             0
# 3                  0                3             0
# 4                  1                0             1

# %%
X_new_pca = pca.transform(X_new_scaled)

# %%
import matplotlib.pyplot as plt

# Crear el gráfico PCA
plt.figure(figsize=(8,6))
scatter = plt.scatter(X_new_pca[:, 0], X_new_pca[:, 1],
                      c=data_new['cluster_pred'], alpha=0.8)

# Etiquetas y título
plt.xlabel('Componente principal 1')
plt.ylabel('Componente principal 2')
plt.title('Visualización PCA - Nuevos Datos')
plt.grid(True)
plt.show()
